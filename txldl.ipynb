# %% [markdown]
# <a href="https://colab.research.google.com/github/ThunderHuy/thuthaptienxulydulieu/blob/main/txldl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Get the data for the stock Apple, Google</h1>

# %%
dataAAPL = yf.download('AAPL', '2021-01-01', '2023-10-31')
dataGOOG = yf.download('GOOG', '2021-01-01', '2023-10-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# <h1>Show data Apple, Google</h1>

# %%
dataAAPL.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  127.164154
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  128.736404
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  124.402931
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  128.647949
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  129.758362
# 2021-01-11  129.190002  130.169998  128.500000  128.979996  126.741615
# 2021-01-12  128.500000  129.690002  126.860001  128.800003  126.564751
# 2021-01-13  128.759995  131.449997  128.490005  130.889999  128.618515
# 2021-01-14  130.800003  131.000000  128.759995  128.910004  126.672836
# 2021-01-15  128.779999  130.220001  127.000000  127.139999  124.933540
#
#                Volume
# Date
# 2021-01-04  143301900
# 2021-01-05   97664900
# 2021-01-06  155088000
# 2021-01-07  109578200
# 2021-01-08  105158200
# 2021-01-11  100384500
# ...

# %%
dataGOOG.head(10)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-01-04  87.876999  88.032501  85.392502  86.412003  86.412003  38038000
# 2021-01-05  86.250000  87.383499  85.900749  87.045998  87.045998  22906000
# 2021-01-06  85.131500  87.400002  84.949997  86.764503  86.764503  52042000
# 2021-01-07  87.002998  89.419998  86.852501  89.362503  89.362503  45300000
# 2021-01-08  89.399002  90.491997  88.676750  90.360497  90.360497  41012000
# 2021-01-11  89.303497  89.715752  88.026001  88.335999  88.335999  24194000
# 2021-01-12  87.695999  88.902000  86.265503  87.327499  87.327499  27140000
# 2021-01-13  86.929001  88.251747  86.900497  87.720001  87.720001  21882000
# 2021-01-14  87.681000  88.750504  86.669998  87.009003  87.009003  23590000
# 2021-01-15  86.909500  87.800003  86.077499  86.809502  86.809502  26844000

# %% [markdown]
# <h1>Summary for quantitative columns</h1>

# %%
dataAAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  711.000000  711.000000  711.000000  711.000000  711.000000
# mean   153.969621  155.726526  152.350309  154.106554  152.799165
# std     18.569957   18.607307   18.575249   18.591145   18.916838
# min    119.029999  120.400002  116.209999  116.360001  114.511490
# 25%    140.614998  142.849998  138.245003  140.925003  139.501411
# 50%    150.899994  153.000000  149.360001  151.029999  149.912247
# 75%    170.074997  171.845001  168.345001  170.250000  168.854866
# max    196.240005  198.229996  195.279999  196.449997  195.926956
#
#              Volume
# count  7.110000e+02
# mean   8.083651e+07
# std    2.757499e+07
# min    3.145820e+07
# 25%    6.024555e+07
# 50%    7.583400e+07
# 75%    9.440090e+07
# max    1.954327e+08

# %%
dataGOOG.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  711.000000  711.000000  711.000000  711.000000  711.000000
# mean   119.123521  120.548210  117.842947  119.204826  119.204826
# std     17.617757   17.541008   17.503729   17.510082   17.510082
# min     85.131500   86.550003   83.449997   83.489998   83.489998
# 25%    103.752251  105.409252  102.901875  104.501999  104.501999
# 50%    119.589996  120.985001  118.684998  119.620003  119.620003
# 75%    134.934998  136.554001  133.404243  135.260498  135.260498
# max    151.863495  152.100006  149.887497  150.709000  150.709000
#
#              Volume
# count  7.110000e+02
# mean   2.677612e+07
# std    1.059866e+07
# min    8.567800e+06
# 25%    1.978030e+07
# 50%    2.417010e+07
# 75%    3.098015e+07
# max    9.779860e+07

# %% [markdown]
# <h1>Visualize Open and Close Apple</h1>

# %%
date =  dataAAPL.index
plt.plot(date, dataAAPL.Close, label = "Close")
plt.plot(date, dataAAPL.Open, label = "Open")
plt.legend(title = "Apple Inc", loc = 'upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>Visualize Open and Close Google</h1>

# %%
date =  dataAAPL.index
plt.plot(date, dataGOOG.Close, label = "Close")
plt.plot(date, dataGOOG.Open, label = "Open")
plt.legend(title = "Google Inc", loc = 'upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>Visualze Open Apple, Google</h1>

# %%
date =  dataAAPL.index
plt.plot(date, dataGOOG.Open, label = "Google")
plt.plot(date, dataAAPL.Open, label = "Apple")
plt.legend(title = "Company")
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <h1>Visualze volume Apple, Google</h1>

# %%
date =  dataAAPL.index
plt.plot(date, dataAAPL.Volume, label = "Apple")
plt.plot(date, dataGOOG.Volume, label = "Google")
plt.legend(title = "Volume", loc = 'upper left')
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
